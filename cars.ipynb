# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/cars.csv")
df
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0    14.0           8          350  165       4209           12   1972
# 1    31.9           4           89   71       1925           14   1980
# 2    17.0           8          302  140       3449           11   1971
# 3    15.0           8          400  150       3761           10   1971
# 4    30.5           4           98   63       2051           17   1978
# ..    ...         ...          ...  ...        ...          ...    ...
# 256  17.0           8          305  130       3840           15   1980
# 257  36.1           4           91   60       1800           16   1979
# 258  22.0           6          232  112       2835           15   1983
# 259  18.0           6          232  100       3288           16   1972
# 260  22.0           6          250  105       3353           15   1977
#
#         brand
# 0         US.
# 1     Europe.
# 2         US.
# 3         US.
# 4         US.
# ..        ...
# ...

# %%
df.head()
# Out:
#     mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year     brand
# 0  14.0           8          350  165       4209           12   1972       US.
# 1  31.9           4           89   71       1925           14   1980   Europe.
# 2  17.0           8          302  140       3449           11   1971       US.
# 3  15.0           8          400  150       3761           10   1971       US.
# 4  30.5           4           98   63       2051           17   1978       US.

# %%
df.tail()
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 256  17.0           8          305  130       3840           15   1980
# 257  36.1           4           91   60       1800           16   1979
# 258  22.0           6          232  112       2835           15   1983
# 259  18.0           6          232  100       3288           16   1972
# 260  22.0           6          250  105       3353           15   1977
#
#        brand
# 256      US.
# 257   Japan.
# 258      US.
# 259      US.
# 260      US.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           261 non-null    float64
#  1    cylinders    261 non-null    int64
#  2    cubicinches  261 non-null    object
#  3    hp           261 non-null    int64
#  4    weightlbs    261 non-null    object
#  5    time-to-60   261 non-null    int64
#  6    year         261 non-null    int64
#  7    brand        261 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 16.4+ KB

# %%
df.dtypes
# Out:
# mpg             float64
#  cylinders        int64
#  cubicinches     object
#  hp               int64
#  weightlbs       object
#  time-to-60       int64
#  year             int64
#  brand           object
# dtype: object

# %%
df.size
# Out:
# 2088

# %%
df.isnull()
# Out:
#        mpg   cylinders   cubicinches     hp   weightlbs   time-to-60   year  \
# 0    False       False         False  False       False        False  False
# 1    False       False         False  False       False        False  False
# 2    False       False         False  False       False        False  False
# 3    False       False         False  False       False        False  False
# 4    False       False         False  False       False        False  False
# ..     ...         ...           ...    ...         ...          ...    ...
# 256  False       False         False  False       False        False  False
# 257  False       False         False  False       False        False  False
# 258  False       False         False  False       False        False  False
# 259  False       False         False  False       False        False  False
# 260  False       False         False  False       False        False  False
#
#       brand
# 0     False
# 1     False
# 2     False
# ...

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
df["cubicinches"] = pd.to_numeric(df["cubicinches"], errors="coerce")
df["weightlbs"] = pd.to_numeric(df["weightlbs"], errors="coerce")

# %%
#1. Improvement in mpg over the years
plt.figure(figsize=(10, 5))
sns.lineplot(x=df["year"], y=df["mpg"], estimator="mean", ci=None)
plt.xlabel("Year")
plt.ylabel("Average MPG")
plt.title("MPG Trend Over the Years")
plt.show()
# Out:
# <ipython-input-14-f674428a8917>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=df["year"], y=df["mpg"], estimator="mean", ci=None)

# %%
#2. affect of cubicinches to reach 60 miles per hour
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df["cubicinches"], y=df["time-to-60"])
plt.xlabel("Cubic Inches")
plt.ylabel("Time to 60 mph (seconds)")
plt.title("Effect of Engine Size on Acceleration")
plt.show()

# %%
#3. Does a specific country prefer vehicles with more horsepower?
plt.figure(figsize=(10, 5))
sns.boxplot(x=df["brand"], y=df["hp"])
plt.xlabel("Country of Origin")
plt.ylabel("Horsepower")
plt.title("Horsepower Preference by Country")
plt.show()

# %%
#4. how does horse power affect average?
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df["hp"], y=df["mpg"])
plt.xlabel("Horsepower")
plt.ylabel("MPG")
plt.title("Horsepower vs. Fuel Efficiency")
plt.show()

# %%
#5. how does cubicinches affects average?
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df["cubicinches"], y=df["mpg"])
plt.xlabel("Cubic Inches")
plt.ylabel("MPG")
plt.title("Engine Size vs. Fuel Efficiency")
plt.show()

# %%
#6. effect of cylinders of mpg
plt.figure(figsize=(10, 5))
sns.boxplot(x=df["cylinders"], y=df["mpg"])
plt.xlabel("Number of Cylinders")
plt.ylabel("MPG")
plt.title("Cylinders vs. Fuel Efficiency")
plt.show()

# %%
#7. Relation between cubic inches , number of cylinders , horsepower
sns.pairplot(df, vars=["cubicinches", "cylinders", "hp"], kind="reg")
plt.show()

# %%
#8. Proportion of vehicles with 8 cylinders
cyl_8_proportion = (df[df["cylinders"] == 8].shape[0] / df.shape[0]) * 100
print(f"Proportion of vehicles with 8 cylinders: {cyl_8_proportion:.2f}%")
# Out:
# Proportion of vehicles with 8 cylinders: 29.12%

# %%
# 9. Direct proportion between cubic inches, cylinders, and horsepower
sns.heatmap(df[["cubicinches", "cylinders", "hp"]].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation between Cubic Inches, Cylinders, and Horsepower")
plt.show()

# %%
#10. Inverse proportion between horsepower and MPG
correlation = df["hp"].corr(df["mpg"])
print(f"Correlation between Horsepower and MPG: {correlation:.2f}")
# Out:
# Correlation between Horsepower and MPG: -0.77

# %%
data_wo_year = df[['brand', 'mpg', 'cylinders']] # Select relevant columns

# %%
data_wo_year['brand'] = data_wo_year['brand'].astype(str)
data_3d = data_wo_year.replace({" US.":0," Europe.":1," Japan.":2})
# Out:
# <ipython-input-29-51c1ab09512d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_wo_year['brand'] = data_wo_year['brand'].astype(str)
# <ipython-input-29-51c1ab09512d>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_3d = data_wo_year.replace({" US.":0," Europe.":1," Japan.":2})

# %%
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

sns.set(style = "darkgrid")

# Assuming 'df' is your original dataframe with the car data
data_wo_year = df[['brand', 'mpg', 'cylinders']]
data_wo_year['brand'] = data_wo_year['brand'].astype(str)

# Creating figure
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

data_3d = data_wo_year.replace({" US.":0," Europe.":1," Japan.":2})


x = data_3d['brand']
y = data_3d['mpg']
z = data_3d['cylinders']

ax.set_xlabel("Brands")
ax.set_ylabel("Miles per gallon")
ax.set_zlabel("No of Cylinders")

ax.scatter(x, y, z)

plt.show()
# Out:
# <ipython-input-30-c9a88e15b69b>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_wo_year['brand'] = data_wo_year['brand'].astype(str)
# <ipython-input-30-c9a88e15b69b>:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_3d = data_wo_year.replace({" US.":0," Europe.":1," Japan.":2})

# %%
plt.pie(data_wo_year.cylinders.value_counts(),labels = ["4 Cylinder","8 Cylinder","6 Cylinder","5 Cylinder","3 Cylinder"],autopct='%1.1f%%',shadow = True,radius= 2)
plt.legend(loc = "upper right")
